# %%
import pandas as pd
import requests
import time
from sklearn.preprocessing import LabelEncoder

# Load datasets
moody_lyrics_path = 'datasets/MoodyLyrics4Q.csv'
allmusic_lyrics_path = 'datasets/Dataset-AllMusic-771Lyrics.csv'

moody_lyrics = pd.read_csv(moody_lyrics_path)
allmusic_lyrics = pd.read_csv(allmusic_lyrics_path, encoding='latin1')

# Remove index columns
if 'index' in moody_lyrics.columns:
    moody_lyrics.drop(columns=['index'], inplace=True)
if 'Name' in allmusic_lyrics.columns:
    allmusic_lyrics.drop(columns=['Name'], inplace=True)
print("Index columns removed from datasets.")

# Replace "_" with " " in Dataset-AllMusic-771 and classification replacements
allmusic_lyrics.replace('_', ' ', regex=True, inplace=True)
allmusic_lyrics.replace('  ', ' ', regex=True, inplace=True)
classification_replacements = {'Q1': 'happy', 'Q2': 'angry', 'Q3': 'sad', 'Q4': 'relaxed'}
allmusic_lyrics['Classification'].replace(classification_replacements, inplace=True)
print(f"Classification replacements done: Q1 = happy, Q2 = angry, Q3 = sad, Q4 = relaxed.")

# Standardize column names
moody_lyrics.rename(columns={'title': 'title', 'artist': 'artist', 'mood': 'mood'}, inplace=True)
allmusic_lyrics.rename(columns={'Title': 'title', 'Artist': 'artist', 'Classification': 'mood'}, inplace=True)
print(f"Column names were standardized.")

# Merge datasets vertically
merged_dataset = pd.concat([moody_lyrics, allmusic_lyrics], ignore_index=True)
print("Datasets merged into a unique dataset.")

# Remove rows with NaN values
initial_row_count = merged_dataset.shape[0]
merged_dataset.dropna(inplace=True)
nan_removed_count = initial_row_count - merged_dataset.shape[0]
print(f"Removed {nan_removed_count} rows containing NaN values.")

# Remove duplicate rows
initial_row_count = merged_dataset.shape[0]
merged_dataset.drop_duplicates(inplace=True)
duplicates_removed_count = initial_row_count - merged_dataset.shape[0]
print(f"Removed {duplicates_removed_count} duplicate rows.")

# Keep original categorical data and convert to numerical
merged_dataset['original_mood'] = merged_dataset['mood']
le = LabelEncoder()
merged_dataset['mood'] = le.fit_transform(merged_dataset['mood'])
print("Categorical data converted to numerical.")

# Function to get lyrics from Musixmatch
def get_lyrics(song_name, artist_name, api_keys):
    base_url = "https://api.musixmatch.com/ws/1.1/"
    
    for api_key in api_keys:
        # Endpoint to search for the track
        search_url = f"{base_url}track.search"
        search_params = {
            'q_track': song_name,
            'q_artist': artist_name,
            'apikey': api_key,
            'f_has_lyrics': 1
        }
        
        # Making the request to search for the track
        response = requests.get(search_url, params=search_params)
        data = response.json()
        
        if data['message']['header']['status_code'] != 200:
            continue
        
        track_list = data['message']['body']['track_list']
        if not track_list:
            continue
        
        # Getting the track ID of the first result
        track_id = track_list[0]['track']['track_id']
        
        # Endpoint to get lyrics
        lyrics_url = f"{base_url}track.lyrics.get"
        lyrics_params = {
            'track_id': track_id,
            'apikey': api_key
        }
        
        # Making the request to get the lyrics
        response = requests.get(lyrics_url, params=lyrics_params)
        data = response.json()
        
        if data['message']['header']['status_code'] != 200:
            continue
        
        lyrics = data['message']['body']['lyrics']['lyrics_body']
        return lyrics
    
    return None

# Fetching lyrics for each song
api_key = ['1611504a22c9c19cbe8b560d42d4a896','b76a1b9a47064853d3363d46e5352e79']
missing_lyrics_count = 0

def fetch_lyrics(row):
    global missing_lyrics_count
    lyrics = get_lyrics(row['title'], row['artist'], api_key)
    if lyrics is None:
        print(f"No lyrics found for '{row['title']}' by {row['artist']}")
        missing_lyrics_count += 1
    return lyrics

merged_dataset['lyrics'] = merged_dataset.apply(fetch_lyrics, axis=1)
initial_row_count = merged_dataset.shape[0]
print("Lyrics fetched and added to the dataset.")
print(f"Total songs in dataset: {initial_row_count}")
print(f"Total songs without lyrics: {missing_lyrics_count}")

# Remove rows without lyrics
initial_row_count = merged_dataset.shape[0]
merged_dataset = merged_dataset[merged_dataset['lyrics'].notna()]
lyrics_removed_count = initial_row_count - merged_dataset.shape[0]
print(f"Removed {lyrics_removed_count} rows without lyrics.")
print(f"Total songs in dataset: {merged_dataset.shape[0]}")

# Display the first few rows of the merged dataset
display(merged_dataset.head())

# Save the cleaned dataset with lyrics
merged_dataset.to_csv('cleaned_lyrics_dataset_with_lyrics.csv', index=False)
print("Cleaned dataset with lyrics saved to 'cleaned_dataset_with_lyrics.csv'.")
# Out:
# Index columns removed from datasets.
# Classification replacements done: Q1 = happy, Q2 = angry, Q3 = sad, Q4 = relaxed.
# Column names were standardized.
# Datasets merged into a unique dataset.
# Removed 0 rows containing NaN values.
# Removed 197 duplicate rows.
# Categorical data converted to numerical.
# No lyrics found for '12' by Katatonia
# No lyrics found for 'Jungle Drums' by Emiliana Torrini
# No lyrics found for 'Two Of Those Too (Album Version)' by Maria Taylor
# No lyrics found for 'Everybody Knows That You Are Insane' by Queens Of The Stone Age
# No lyrics found for 'Blue Ridge Mountains' by Haley Bonar
# No lyrics found for 'Sigma' by Secret Garden
# No lyrics found for 'Thick As Thieves (2005 Version)' by Natalie Merchant
# No lyrics found for 'Insomnia (Revised Album Version)' by Tyler Hilton
# No lyrics found for 'Love Thing' by Spice Girls
# No lyrics found for 'Say Yeah' by Acoustic Alchemy
# No lyrics found for 'Dates From Hell' by Remi Nicole
# No lyrics found for 'Bette Davis Eyes (Acoustic Version)' by Kim Carnes
# No lyrics found for 'Fuck you' by Headstones
# No lyrics found for 'Anti-Social' by Anthrax
# No lyrics found for 'Impossible' by Wu-Tang Clan
# No lyrics found for 'Gangsta Gangsta' by N.W.A
# No lyrics found for 'How to Survive in South Central' by Ice Cube
# No lyrics found for 'Die Motherfucker Die' by Dope
# No lyrics found for 'Handsome and Gretel' by Babes In Toyland
# No lyrics found for 'Wake the Dead' by Alice Cooper
# No lyrics found for 'Aika Multaa Muistot (everything Is Nothing)' by Sentenced
# No lyrics found for 'Gritty Shaker' by David Holmes
# No lyrics found for 'The Things I Tell You' by Biosphere
# No lyrics found for 'I Keed (Album Version)' by Triumph the Insult Comic Dog
# No lyrics found for 'Ive Been Wrong Before' by Elvis Costello
# No lyrics found for 'I've Love These Days' by Billy Joel
# No lyrics found for 'Spoonful' by Eric Clapton
# No lyrics found for 'Happy-End' by Michael Rother
# No lyrics found for 'Empty Landscape' by Brian Eno
# No lyrics found for 'Without Love (There Is Nothing)' by Tom Jones
# No lyrics found for 'Im Happy Just to Dance With You' by The Beatles
# No lyrics found for '?nema' by Tool
# No lyrics found for 'Everybodys Crying Mercy' by Elvis Costello
# No lyrics found for 'American Triangle' by Elton John
# No lyrics found for 'Night Games' by Paul Simon
# No lyrics found for 'Cindy C.' by Prince
# No lyrics found for 'Nothings Happening by The' by Chris Rea
# No lyrics found for 'Sick and Tired' by Black Sabbath
# No lyrics found for 'I Can't Wait No Longer (Let's Do This)' by Luther Vandross
# No lyrics found for 'Running Blind' by Randy Travis
# No lyrics found for 'Let's Stick Together' by Bryan Ferry
# No lyrics found for 'Before the World Was Made' by Van Morrison
# No lyrics found for 'Wherever You May Be' by Bonnie Raitt
# No lyrics found for 'Come Back as a Flower' by Stevie Wonder
# No lyrics found for 'Rhythm Is Gonna Get You' by Gloria Estefan
# No lyrics found for 'Build Me Up' by Al Green
# No lyrics found for 'Sleeping Bag' by Beck
# No lyrics found for 'Your Side of the World' by Steven Curtis Chapman
# No lyrics found for 'Hotel' by Tori Amos
# No lyrics found for 'Looking for You' by Kirk Franklin
# No lyrics found for 'Not Just a Ghost's Heart' by Songs: Ohia
# No lyrics found for 'Memories of a Colour' by Stina
# No lyrics found for 'A Satisfied Mind' by Bob Dylan
# No lyrics found for 'Let's Wait Awhile' by Janet Jackson
# No lyrics found for 'If It Weren't For Him' by Vince Gill
# No lyrics found for 'Reaching For the Moon' by Lizz Wright
# No lyrics found for 'Happy Xmas (War Is Over)' by John Lennon
# No lyrics found for 'Pick Up the Oars and Row' by Randy Travis
# No lyrics found for 'Run My Way Runway' by The Boo Radleys
# No lyrics found for 'U Got the Look' by Prince
# No lyrics found for 'Create Me' by Neil Diamond
# No lyrics found for 'North Country Blues' by Bob Dylan
# No lyrics found for 'Night Fever' by Bee Gees
# No lyrics found for 'I'm Talking About You' by Chuck Berry
# No lyrics found for 'Ari's Song' by Nico
# No lyrics found for 'More Than a Woman' by Bee Gees
# No lyrics found for 'Deeper and Deeper' by Madonna
# No lyrics found for 'These Broken Hearts' by Vince Gill
# No lyrics found for 'Mercy' by Prefab Sprout
# No lyrics found for 'Cowboys Like Us' by George Strait
# No lyrics found for 'Breathe in Breathe Out' by Jimmy Buffett
# No lyrics found for 'Melancholy Man' by The Moody Blues
# No lyrics found for 'Do You Remember' by The Beach Boys
# No lyrics found for 'English Rose' by The Jam
# No lyrics found for 'Forty Six 2' by Tool
# No lyrics found for 'If I Were a Carpenter' by Robert Plant
# No lyrics found for 'Animal Farm' by The Kinks
# No lyrics found for 'Why?' by Marian McPartland
# No lyrics found for 'Crush on You' by Bruce Springsteen
# No lyrics found for 'All Day Long' by New Order
# No lyrics found for 'Is There Anybody There' by Scorpions
# No lyrics found for 'These Days' by Jackson Browne
# No lyrics found for 'Ferret Featherbird' by Hamada
# No lyrics found for 'Send One Your Love' by Stevie Wonder
# No lyrics found for 'Memphis in the Meantime' by John Hiatt
# No lyrics found for 'We Got the Love' by George Benson
# No lyrics found for 'Dear Father' by Neil Diamond
# No lyrics found for 'Say You Say Me' by Lionel Richie
# No lyrics found for 'Come Go with Me' by Teddy Pendergrass
# No lyrics found for 'On a Night Like This' by Bob Dylan
# No lyrics found for 'Dream a Little Dream of Me' by Nat King Cole
# No lyrics found for 'I Wonder as I Wonder' by Harry Connick Jr.
# No lyrics found for 'Shall We Gather at the River?' by Randy Travis
# No lyrics found for 'Egg Raid on Mojo [Demo]' by Beastie Boys
# No lyrics found for 'Can't Even Get the Blues No More' by Reba McEntire
# No lyrics found for 'The Unclouded Day' by Randy Travis
# No lyrics found for 'California Sunset' by Neil Young
# No lyrics found for 'How Far Am I from Canaan?' by The Soul Stirrers
# No lyrics found for 'Bob Dylan's Blues' by Bob Dylan
# No lyrics found for 'A Town Called Paradise' by Van Morrison
# No lyrics found for 'Talkin' New York' by Bob Dylan
# No lyrics found for 'Beer for My Horses' by Willie Nelson
# No lyrics found for 'The Rising' by Bruce Springsteen
# No lyrics found for 'My City of Ruins' by Bruce Springsteen
# No lyrics found for 'Think I'm in Love' by Eddie Money
# No lyrics found for 'Juliet' by The Oak Ridge Boys
# No lyrics found for 'Mary's Place' by Bruce Springsteen
# No lyrics found for 'Everything Is Everything' by Earth Wind Fire
# No lyrics found for 'Whatever You Need' by Tina Turner
# No lyrics found for 'Heartbeat' by Wire
# No lyrics found for 'If I Could Only Fly' by Merle Haggard
# No lyrics found for 'Be My Yoko Ono' by Barenaked Ladies
# No lyrics found for 'Daddy Went Walkin'' by Neil Young
# No lyrics found for 'Spam' by Weird Al Yankovic
# No lyrics found for 'Natural Blues' by Moby
# No lyrics found for 'Let It Rain' by Michael W. Smith
# No lyrics found for 'Rock Roll High School' by Ramones
# No lyrics found for 'I'm Hooked on You' by Al Green
# No lyrics found for 'Not Tonight' by Al Green
# No lyrics found for 'Sally' by Sade
# No lyrics found for 'Do You Remember Rock Roll Radio?' by Ramones
# No lyrics found for '(Sittin' On) The Dock of the Bay' by Otis Redding
# No lyrics found for 'Forca' by Nelly Furtado
# No lyrics found for 'I Can't Stop' by Al Green
# No lyrics found for 'The Boulevard of Broken Dreams (Gigolo and Gigolette)' by Tony Bennett
# No lyrics found for 'Don't Be Light' by Air
# No lyrics found for 'I Want You' by Bob Dylan
# No lyrics found for 'Drive My Car' by Bobby McFerrin
# No lyrics found for 'I'm Alright' by Kenny Loggins
# No lyrics found for 'Simple Pleasures' by Bobby McFerrin
# No lyrics found for 'Hickory Wind' by The Byrds
# No lyrics found for 'I Love This Bar' by Toby Keith
# No lyrics found for 'Whiskey Girl' by Toby Keith
# No lyrics found for 'If I Was Jesus' by Toby Keith
# No lyrics found for 'Don't Leave I Think I Love You' by Toby Keith
# No lyrics found for 'Danke Schoen' by Duke Ellington
# No lyrics found for 'I Think It's Going to Rain Today' by Joe Cocker
# No lyrics found for 'It's a Beautiful Day (Reprise)' by Queen
# No lyrics found for 'Help Me Understand' by Trace Adkins
# No lyrics found for 'Don't Tell Me' by Madonna
# No lyrics found for 'F*** You' by Snoop Dogg
# No lyrics found for 'Love Comes Quickly' by Pet Shop Boys
# No lyrics found for 'Easy Money' by Billy Joel
# No lyrics found for 'Just as I Am' by Mahalia Jackson
# No lyrics found for 'You Are So Beautiful' by Al Green
# No lyrics found for 'After All the Good Is Gone' by Conway Twitty
# No lyrics found for 'The Song Is Over' by The Who
# No lyrics found for 'Impressive Instant' by Madonna
# No lyrics found for 'Not Dark Yet' by Bob Dylan
# No lyrics found for 'I'll Lie Myself to Sleep' by Shelby Lynne
# No lyrics found for 'Oh Sister' by Bob Dylan
# No lyrics found for 'I Turned You On' by The Isley Brothers
# No lyrics found for 'Running Dry (Requiem For the Rockets)' by Neil Young
# No lyrics found for 'Let Me Go Rock 'n' Roll' by Kiss
# No lyrics found for 'Alright Hear This' by Beastie Boys
# No lyrics found for 'Moonlight in Vermont' by Billie Holiday
# No lyrics found for 'Too Much Heaven' by Bee Gees
# No lyrics found for 'My Hometown' by Bruce Springsteen
# No lyrics found for 'Upstairs Downtown' by Toby Keith
# No lyrics found for 'Sub-Culture' by New Order
# No lyrics found for 'Come Rain or Come Shine' by Etta James
# No lyrics found for 'I Made the Prison Band' by Merle Haggard
# No lyrics found for 'Fanny (Be Tender With My Love)' by Bee Gees
# No lyrics found for 'I'm Still Not over You' by Ray Price
# No lyrics found for 'Love You Inside Out' by Bee Gees
# No lyrics found for 'If I Had $10000' by Barenaked Ladies
# No lyrics found for 'Four Down and Twelve Across' by George Strait
# No lyrics found for 'Hunter' by Bjork
# No lyrics found for 'Young Man's Town' by Vince Gill
# No lyrics found for 'This Is a Lie' by The Cure
# No lyrics found for 'If I Don't See You Again' by Neil Diamond
# No lyrics found for 'Another Day (That Time Forgot)' by Neil Diamond
# No lyrics found for 'One More Bite of the Apple' by Neil Diamond
# No lyrics found for 'Forgotten' by Neil Diamond
# No lyrics found for 'She Never Cried in Front of Me' by Toby Keith
# No lyrics found for 'The Crane Wife 3' by Marianne Faithfull
# No lyrics found for 'How Many Worlds' by Marianne Faithfull
# No lyrics found for 'In Germany Before the War' by Marianne Faithfull
# No lyrics found for 'Sugar' by Flo Rida
# No lyrics found for 'When I'm Sixty-Four' by The Beatles
# No lyrics found for 'Lovely Rita' by The Beatles
# No lyrics found for 'She's Leaving Home' by The Beatles
# No lyrics found for 'Getting Better' by The Beatles
# No lyrics found for 'Julia' by The Beatles
# No lyrics found for 'Ob-La-Di Ob-La-Da' by The Beatles
# No lyrics found for 'All Together Now' by The Beatles
# No lyrics found for 'Do You Hear What I Hear?' by Bob Dylan
# No lyrics found for 'The First Noel' by Bob Dylan
# No lyrics found for 'O' Little Town Of Bethlehem' by Bob Dylan
# No lyrics found for 'O' Come All Ye Faithful (Adeste Fideles)' by Bob Dylan
# No lyrics found for 'The Handiest Frenchman in the Caribbean' by Jimmy Buffett
# No lyrics found for 'Lucy in the Sky With Diamonds' by Elton John
# No lyrics found for 'L-O-V-E' by Natalie Cole
# No lyrics found for 'Mercyful Fate' by Evil
# No lyrics found for 'It's Still Rock and Roll to Me' by Billy Joel
# No lyrics found for 'I Have a Dream' by ABBA
# No lyrics found for 'If You Gotta Go Go Now' by Bob Dylan
# No lyrics found for 'One Love' by The Prodigy
# No lyrics found for 'Rock-A-Bye' by George Benson
# No lyrics found for 'Signed Sealed Delivered I'm Yours' by Stevie Wonder
# No lyrics found for 'Family Bible' by Willie Nelson
# No lyrics found for 'Here with Me' by Dido
# No lyrics found for 'I Still Miss Someone' by Johnny Cash
# No lyrics found for 'Thank You' by Dido
# No lyrics found for 'Let's Go Crazy' by Prince
# No lyrics found for 'Blue' by The Jayhawks
# No lyrics found for 'Do Me Baby' by Prince
# No lyrics found for 'Never Before' by Deep Purple
# No lyrics found for 'I Feel for You' by Prince
# No lyrics found for 'Chelsea Morning' by Joni Mitchell
# No lyrics found for 'Too Far Gone' by Emmylou Harris
# No lyrics found for 'Sleepless Nights' by Emmylou Harris
# No lyrics found for 'Changes' by Black Sabbath
# No lyrics found for 'I Wanna Be Your Lover' by Prince
# No lyrics found for 'Keep Gettin' It On' by Marvin Gaye
# No lyrics found for 'Out of This World' by The Cure
# No lyrics found for 'I Won't Forget You' by Jim Reeves
# No lyrics found for 'Lazy Days' by Robbie Williams
# No lyrics found for 'Hippy Hippy Shake' by The Beatles
# No lyrics found for 'F**k Wit Me Now' by Lil Wayne
# No lyrics found for 'Love Don't Cost a Thing' by Jennifer Lopez
# No lyrics found for 'Around and Around' by The Rolling Stones
# No lyrics found for 'Calling Dr. Love' by Kiss
# No lyrics found for 'Procession' by New Order
# No lyrics found for 'Be-Bop-A-Lula' by Gene Vincent
# No lyrics found for 'Potential New Boyfriend' by Dolly Parton
# No lyrics found for 'Fire and Rain' by Willie Nelson
# No lyrics found for 'Glory Days' by Bruce Springsteen
# No lyrics found for 'Moonglow' by Lionel Hampton
# No lyrics found for 'As Usual' by Brenda Lee
# No lyrics found for 'Good Good Lovin'' by James Brown
# No lyrics found for 'Old Apache Squaw' by Johnny Cash
# No lyrics found for 'Merry Christmas Baby' by Chuck Berry
# No lyrics found for 'What Is Life' by George Harrison
# No lyrics found for 'It Hasn't Happened Yet' by Rosanne Cash
# No lyrics found for 'Last Night I Dreamt That Somebody Loved Me' by The Smiths
# No lyrics found for 'Blue Monday' by New Order
# No lyrics found for 'When I Get Home' by The Beatles
# No lyrics found for 'Oh Pretty Woman' by Al Green
# No lyrics found for 'All I Want for Christmas Is You' by Mariah Carey
# No lyrics found for 'Paralyzed' by Elvis Presley
# No lyrics found for 'Lush Life' by Ella Fitzgerald
# No lyrics found for 'C11H17N202SNA (Sodium Pentathol)' by Anthrax
# No lyrics found for 'Just One Look' by Linda Ronstadt
# No lyrics found for 'Full Force Gale' by Van Morrison
# No lyrics found for '1982' by Randy Travis
# No lyrics found for 'Door Peep' by Burning Spear
# No lyrics found for 'Great Balls of Fire' by Dolly Parton
# No lyrics found for 'Freedom' by George Michael
# No lyrics found for 'Silent Night' by Boyz II Men
# No lyrics found for 'Upside Down' by Diana Ross
# No lyrics found for 'Circle of Friends' by Point of Grace
# No lyrics found for 'Neon Moon' by Brooks Dunn
# No lyrics found for 'Ben' by Michael Jackson
# No lyrics found for 'Private Eyes' by Daryl Hall John Oates
# No lyrics found for 'Blandest' by Nirvana
# No lyrics found for 'Tired of Waiting for You' by The Kinks
# No lyrics found for 'One Voice' by Barry Manilow
# No lyrics found for 'Daydream' by The Lovin' Spoonful
# No lyrics found for 'Plastic Man' by The Kinks
# No lyrics found for 'The Drugs Don't Work' by The Verve
# No lyrics found for 'Guess My Eyes Were Bigger Than My Heart' by Conway Twitty
# No lyrics found for 'I Can't Stop Loving You' by Conway Twitty
# No lyrics found for 'Darling You Know I Wouldn't Lie' by Conway Twitty
# No lyrics found for 'I Wonder What She'll Think About Me Leaving' by Conway Twitty
# No lyrics found for 'You're Only Human (Second Wind)' by Billy Joel
# No lyrics found for 'How Much More Can She Stand' by Conway Twitty
# No lyrics found for 'I Went to Your Wedding' by Hank Snow
# No lyrics found for 'I Saw Her Standing There' by Paul McCartney
# No lyrics found for 'My Love' by Paul McCartney
# No lyrics found for 'Tweedle Dee and Tweedle Dum' by Bob Dylan
# No lyrics found for 'No Money Down' by Chuck Berry
# No lyrics found for 'Almost Grown' by Chuck Berry
# No lyrics found for 'You Took the Words Right Out of My Mouth (Hot Summer Night)' by Meat Loaf
# No lyrics found for 'My Favorite Mistake' by Sheryl Crow
# No lyrics found for 'A Change Would Do You Good' by Sheryl Crow
# No lyrics found for 'Strong Enough' by Sheryl Crow
# No lyrics found for 'Least of All' by George Jones
# No lyrics found for 'Lovable' by Elvis Costello
# No lyrics found for 'Coming on Strong' by Brenda Lee
# No lyrics found for 'Triple Trouble' by Beastie Boys
# No lyrics found for 'Foxey Lady' by Jimi Hendrix
# No lyrics found for 'A Place to Fall Apart' by Merle Haggard
# No lyrics found for 'Party Line' by The Kinks
# No lyrics found for 'A House in the Country' by The Kinks
# No lyrics found for 'Jingle Bells' by Barenaked Ladies
# No lyrics found for 'Signs' by Snoop Dogg
# No lyrics found for 'Fruitcakes' by Jimmy Buffett
# No lyrics found for 'House on the Lake' by Rosanne Cash
# No lyrics found for 'Love in Bloom' by Bing Crosby
# No lyrics found for '(Don't Worry) If There's a Hell Below We're All Going to Go' by Curtis Mayfield
# No lyrics found for 'I Run S***' by DMX
# No lyrics found for 'Leonard' by Merle Haggard
# No lyrics found for 'His Eyes' by Steven Curtis Chapman
# No lyrics found for 'Lord of the Dance' by Steven Curtis Chapman
# No lyrics found for 'Don't Make Me' by Blake Shelton
# No lyrics found for 'Bron-Y-Aur Stomp' by Led Zeppelin
# No lyrics found for 'All of Me' by 50 Cent
# No lyrics found for 'Do It Well' by Jennifer Lopez
# No lyrics found for 'Feedback' by Janet Jackson
# No lyrics found for 'Close the Door' by Teddy Pendergrass
# No lyrics found for 'TV Crimes' by Black Sabbath
# No lyrics found for 'Dreamland Express' by John Denver
# No lyrics found for 'AmeriKKKa's Most Wanted' by Ice Cube
# No lyrics found for 'Wrap Her Up' by Elton John
# No lyrics found for 'Express Yourself' by Madonna
# No lyrics found for 'Play' by Jennifer Lopez
# No lyrics found for 'I Ain't With Being Broke' by Geto Boys
# No lyrics found for 'Baby I'm Burnin'' by Dolly Parton
# No lyrics found for 'It's Still Rock Roll to Me' by Billy Joel
# No lyrics found for 'Like a Virgin' by Madonna
# No lyrics found for 'Blue Hawaii' by Bing Crosby
# No lyrics found for 'Dirty Mind' by Prince
# No lyrics found for 'Charlie' by Split Enz
# No lyrics found for 'Friends' by Michael W. Smith
# No lyrics found for 'Where or When' by Lena Horne
# No lyrics found for 'Sweet Leilani' by Bing Crosby
# No lyrics found for 'That's What Friends Are For' by Dionne Warwick
# No lyrics found for 'Waterloo Sunset' by The Kinks
# No lyrics found for 'You Are Here' by John Lennon
# No lyrics found for 'Take Me Home Country Roads' by John Denver
# No lyrics found for 'April Come She Will' by Simon Garfunkel
# No lyrics found for 'Door Peep' by Sinead O'Connor
# No lyrics found for 'Tenderly' by Rosemary Clooney
# No lyrics found for 'Farewell Andromeda (Welcome to My Morning)' by John Denver
# No lyrics found for 'Dixie Lily' by Elton John
# Lyrics fetched and added to the dataset.
# Total songs in dataset: 2574
# Total songs without lyrics: 326
# Removed 326 rows without lyrics.
# Total songs in dataset: 2248
#            artist               title  mood original_mood  \
# 0  George Michael     I Want Your Sex     1         happy
# 1      Rob Zombie        Pussy Liquor     0         angry
# 3     Bing Crosby  Swinging On A Star     1         happy
# 4        Ludacris            Get Back     0         angry
# 5            Hole              Violet     0         angry
#
#                                               lyrics
# 0  There's things that you guess\nAnd things that...
# 1  Earl had a baby\nBaby was her name\nHe knew sh...
# 3  Would you like to swing on a star\nCarry moonb...
# 4  Heads up (woop, woop)\nHeads up (woop, woop)\n...
# 5  And the sky was made of amethyst\nAnd all the ...
# Cleaned dataset with lyrics saved to 'cleaned_lyrics_dataset_with_lyrics.csv'.
